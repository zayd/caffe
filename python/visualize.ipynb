# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os
import re
import time
import images2gif
import math

from IPython.display import HTML
from IPython.display import Image
# %matplotlib inline

caffe_root = '../'
net_root = caffe_root + 'examples/cfw/'
data_root = caffe_root + 'data/cfw/'
subdirectory = '4layers_v9/'

DEPLOY_FILE = 'cfw_deploy.prototxt'
MEAN_FILE = 'mean.binaryproto'
TEST_FILE = 'cfw_test.txt'
TRAIN_FILE = 'cfw_train_random.txt'
LABELS_FILE = 'cfw_labels.txt'

import sys
sys.path.insert(0, caffe_root + 'python')
sys.path.insert(0, net_root)

import caffe

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'

# %% [markdown]
# ### Helper Functions

# %%
# Human Sorting
def tryint(s):
    try:
        return int(s)
    except:
        return s
     
def alphanum_key(s):
    """ Turn a string into a list of string and number chunks.
        "z23a" -> ["z", 23, "a"]
    """
    return [ tryint(c) for c in re.split('([0-9]+)', s) ]

def sort_nicely(l):
    """ Sort the given list in the way that humans expect.
    """
    l.sort(key=alphanum_key)
    
# our network takes BGR images, so we need to switch color channels
def switch_color(im):
    if im.ndim == 3:
        im = im[:, :, ::-1]
    
    return im 

def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    return data

def vis_filters_rect(data, n, padsize=1, padval=0):
    # make a rectangle by dividing one dimension by the other
    m = data.shape[0] / n
    padding = ((0, n * m - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))

    # tile the filters into an image
    data = data.reshape((n, m) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], m * data.shape[3]) + data.shape[4:])
    return data

def normalize_matrix(data, type='global'):
    if type == 'global':
        data -= data.min()
        data /= data.max()
    elif type == 'rowwise':
        for i in range(data.shape[0]):
            data[i, :] /= abs(data[i, :]).max()
    elif type == 'colwise':
        for i in range(data.shape[1]):
            data[:, i] /= abs(data[:, i]).max()
    else:
        print "norm type unknown"
    return data

# %%
filenames = os.listdir(net_root + subdirectory)
filenames = filter(lambda f: not re.search(r'\d+$', f) == None, filenames)
sort_nicely(filenames)

all_filters = []
all_filters2 = []
all_filters3 = []
all_ip1 = []

print net_root + DEPLOY_FILE
print net_root + subdirectory + filenames[1]

net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + filenames[1])

filters = net.params['conv1'][0].data
data = vis_filters_rect(filters.transpose(0, 2, 3, 1), 10)

filters2 = net.params['conv2'][0].data
(num_filters2, num_channels2, _, _) = filters2.shape

filters3 = net.params['conv3'][0].data
(num_filters3, num_channels3, _, _) = filters3.shape

for f in filenames:
    print net_root + f
    net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + f)
    filters = net.params['conv1'][0].data
    filters2 = net.params['conv2'][0].data
    filters3 = net.params['conv3'][0].data
    ip1 = net.params['ip1'][0].data
    ip1 = ip1.reshape(1024, 10, 23, 17)
    ip1 = abs(ip1)
    ip1_i = normalize_matrix(ip1, type='global')
    i = 9
    ip1_i = ip1[i]
    #filters3 = net.params['ip1'][0].data
    #filters3 = filters3.squeeze()[:1024] # display first 1024 dim
    #filters3 *= 1.0/filters3.max()
    filters = normalize_matrix(filters, type='colwise')
    filters = normalize_matrix(filters, type='global')
    filters2 = normalize_matrix(filters2, type='colwise')
    filters2 = normalize_matrix(filters2, type='global')
    filters3 = normalize_matrix(filters3, type='colwise')
    filters3 = normalize_matrix(filters3, type='global')
    all_filters.append(vis_filters_rect(filters.transpose(0, 2, 3, 1), 10))
    all_filters2.append(vis_filters_rect(filters2.reshape(num_filters2*num_channels2, 5, 5), 40))
    all_filters3.append(vis_filters_rect(filters3.reshape(num_filters3*num_channels3, 5, 5), 60))
    all_ip1.append(vis_filters_rect(ip1_i, 2))
    #all_filters3.append(filters3)

images2gif.writeGif('one.gif', all_filters, duration=0.8)
images2gif.writeGif('two.gif', all_filters2, duration=0.8)
images2gif.writeGif('three.gif', all_filters3, duration=0.8)
images2gif.writeGif('ip.gif', all_ip1, duration=0.8)
# Out:
# ../examples/cfw/cfw_deploy.prototxt
# ../examples/cfw/4layers_v9/cfw_iter_1000
# ../examples/cfw/cfw_iter_500
# ../examples/cfw/cfw_iter_1000
# ../examples/cfw/cfw_iter_1500
# ../examples/cfw/cfw_iter_2000
# ../examples/cfw/cfw_iter_2500
# ../examples/cfw/cfw_iter_3000
# ../examples/cfw/cfw_iter_3500
# ../examples/cfw/cfw_iter_4000
# ../examples/cfw/cfw_iter_4500
# ../examples/cfw/cfw_iter_5000
# ../examples/cfw/cfw_iter_5500
# ../examples/cfw/cfw_iter_6000
# ../examples/cfw/cfw_iter_6500
# ../examples/cfw/cfw_iter_7000
# ../examples/cfw/cfw_iter_7500
# ../examples/cfw/cfw_iter_8000
# ../examples/cfw/cfw_iter_8500
# ../examples/cfw/cfw_iter_9000
# ../examples/cfw/cfw_iter_9500
# ../examples/cfw/cfw_iter_10000
# ../examples/cfw/cfw_iter_10500
# ../examples/cfw/cfw_iter_11000
# ../examples/cfw/cfw_iter_11500
# ../examples/cfw/cfw_iter_12000
# ../examples/cfw/cfw_iter_12500
# ../examples/cfw/cfw_iter_13000
# ../examples/cfw/cfw_iter_13500
# ../examples/cfw/cfw_iter_14000
# ../examples/cfw/cfw_iter_14500
# ../examples/cfw/cfw_iter_15000

# %%
from caffe.proto import caffe_pb2
blob = caffe_pb2.BlobProto()
mean_file = open(data_root + MEAN_FILE, "rb").read()
#mean_file = open(caffe_root + 'data/lfw/mean250.binaryproto')
blob.ParseFromString(mean_file)
#print blob
mean = np.array(caffe.io.blobproto_to_array(blob))
print mean.shape
mean = mean[0]
print "Mean shape: " + str(mean.shape)
np.save(data_root + 'mean.npy', mean)

# %%
filenames = os.listdir(net_root + subdirectory)
filenames = filter(lambda f: not re.search(r'\d+$', f) == None, filenames)
sort_nicely(filenames)
f = filenames[-1]

net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + f, channel_swap=(2, 1, 0),
                       mean_file=data_root + 'mean.npy', input_scale=0.00390625)

net.set_phase_train()
net.set_mode_cpu()

print "Loading net: " + net_root + DEPLOY_FILE
print "Snapshot: " + subdirectory + f
# Out:
# Loading net: ../examples/cfw/cfw_deploy.prototxt
# Snapshot: 4layers_v4/cfw_iter_72000

# %% [markdown]
# ### Load Images and Labels

# %%
#NUM_IMAGES = 1382 # NUM_IMAGES in test set
NUM_IMAGES = 128
side = int(np.sqrt(NUM_IMAGES))

with open(data_root + TEST_FILE) as test_file:
    head = [tuple(i.split()) for i in random.choice(list(test_file), NUM_IMAGES)] # random
    #head = [tuple(next(test_file).split()) for i in range(NUM_IMAGES)] # sequential
    names, labels = zip(*head)
    
input_images = [caffe.io.load_image(data_root + n) for n in names]

with open(data_root + LABELS_FILE) as labels_file:
    rows = [line.split(' ') for line in labels_file]
    celeb_names = {row[1][:-1]:row[0] for row in rows}

# %% [markdown]
# ### Plot test sample

# %%
# FOR TEST: CHECK HOW PREDICTION ZERO PADS
prediction = net.predict(input_images, oversample=False)
top = np.argmax(prediction, axis=1)

acc = 0
for l, t in zip(labels, top):
    if int(l) == int(t):
        acc += 1
print "Accuracy: " + str(acc/float(len(labels)))
# Out:
# Accuracy: 0.875

# %%
side = 6
fig, ax = plt.subplots(side, side)
fig.tight_layout()

for i in range(side):
    for j in range(side):
        im = plt.imread(data_root + names[i*side + j])
        ax[i][j].imshow(im)
        ax[i][j].set_xticklabels([])
        ax[i][j].set_yticklabels([])
        ax[i][j].set_title(celeb_names[labels[i*side + j]] + '\n' + 
                           celeb_names[str(top[i*side + j])], fontsize=10)

# %%
#print net.blobs.keys()
#print net.blobs.values()

#print net.blobs['ip1'].data.shape
print top
# Out:
# [   0    1  114 ...,  889 1580 1494]
